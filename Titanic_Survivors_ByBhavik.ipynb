# %% [markdown]
# # **TITANIC SURVIVOR ANALYSIS**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # READING DATA USING PANDAS

# %% [markdown]
# We use pandas read_csv function to read the csv file in python and pandas DataFrame method to convert filr into the data frame.

# %%
df = pd.DataFrame(pd.read_csv('/content/train.csv'))
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# ## **Description of the attributes of the dataset**

# %% [markdown]
# Pclass: Passenger Class (1 = 1st,2 = 2nd;3 = 3rd)
# survival: survival (0 = No;1 = Yes)
# name: Name
# sex: Sex
# age: Age
# sibsp: Number of Siblings/Spouses Aboard
# parch: Number of parents/Children Aboard
# ticket: Ticket Number
# fare: passenger fare (British pound)
# cabin: Cabin
# embarked: Port of Embarkation(C = Cherbourg; Q = Queenstown; S = Southampton)

# %% [markdown]
# # **HANDELING NULL VALUES**

# %% [markdown]
# The dataset may contains many rows and columns for which some values are missing, we can't leave those missing  values as it is.
# In such cases we have two option:
# 1. Either drop the entire row or column
# 2. Fill the missing values with some appropriate values let's say mean of all the values for that column may do the job.

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## **Seperating out the columns which have more than 35% of the values missing in the values dataset**

# %%
x = df.isnull().sum()

drop_col = x[x>(35/100 * df.shape[0])]
drop_col
# Out:
# Cabin    687
# dtype: int64

# %% [markdown]
# Note: There is no specific number after which you should drop the column.It's just that we decided that on oun according to what we want.

# %%
drop_col.index
# Out:
# Index(['Cabin'], dtype='object')

# %%
df.drop(drop_col.index, axis=1, inplace=True)
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %%
df.fillna(df.mean(), inplace = True)
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %% [markdown]
# Because Embarked contains string values, we see the details of that column seperately from others as strings does not have mean and all.

# %%
df['Embarked'].describe()
# Out:
# count     889
# unique      3
# top         S
# freq      644
# Name: Embarked, dtype: object

# %% [markdown]
# For Embarked attribute, we fill the NULL values with the most frequent value in the column.

# %%
df['Embarked'].fillna('s',inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass  ...     SibSp     Parch      Fare
# PassengerId     1.000000 -0.005007 -0.035144  ... -0.057527 -0.001652  0.012658
# Survived       -0.005007  1.000000 -0.338481  ... -0.035322  0.081629  0.257307
# Pclass         -0.035144 -0.338481  1.000000  ...  0.083081  0.018443 -0.549500
# Age             0.033207 -0.069809 -0.331339  ... -0.232625 -0.179191  0.091566
# SibSp          -0.057527 -0.035322  0.083081  ...  1.000000  0.414838  0.159651
# Parch          -0.001652  0.081629  0.018443  ...  0.414838  1.000000  0.216225
# Fare            0.012658  0.257307 -0.549500  ...  0.159651  0.216225  1.000000
#
# [7 rows x 7 columns]

# %% [markdown]
# ### sibsp: Number of Siblings/Spouses Aboard
# ### parch: NUmber of Parents/Children Aboard

# %% [markdown]
# se we can make a new column family_size by combining these two columns

# %%
df['FamilySize'] = df['SibSp']+df['Parch']
df.drop(['SibSp','Parch'], axis=1, inplace=True)
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age      Fare  FamilySize
# PassengerId     1.000000 -0.005007 -0.035144  0.033207  0.012658   -0.040143
# Survived       -0.005007  1.000000 -0.338481 -0.069809  0.257307    0.016639
# Pclass         -0.035144 -0.338481  1.000000 -0.331339 -0.549500    0.065997
# Age             0.033207 -0.069809 -0.331339  1.000000  0.091566   -0.248512
# Fare            0.012658  0.257307 -0.549500  0.091566  1.000000    0.217138
# FamilySize     -0.040143  0.016639  0.065997 -0.248512  0.217138    1.000000

# %% [markdown]
# ### FamilySize in the ship does not have much correlance with survival rate
# Let's check if we weather the person was alone or not can affect the survival rate.

# %%
df['Alone'] = [0 if df['FamilySize'][i]>0 else 1 for i in df.index]
df.head()
# Out:
#    PassengerId  Survived  Pclass  ... Embarked FamilySize  Alone
# 0            1         0       3  ...        S          1      0
# 1            2         1       1  ...        C          1      0
# 2            3         1       3  ...        S          0      1
# 3            4         1       1  ...        S          1      0
# 4            5         0       3  ...        S          0      1
#
# [5 rows x 11 columns]

# %%
df.groupby(['Alone'])['Survived'].mean()
# Out:
# Alone
# 0    0.505650
# 1    0.303538
# Name: Survived, dtype: float64

# %% [markdown]
# ### If the person is alone he/she has less chance of surviving.

# %% [markdown]
# The reason might be the person who is traveling with his family might be belonging to rich class and might be prioritized over other.

# %%
df[['Alone','Face']].corr()

# %% [markdown]
# so we can see if the person was not alone, the chance the ticket price is higher is high.

# %%
df['Sex'] = [0 if df['Sex'][i]=='male' else 1 for i in df.index]
df.groupby(['Sex'])['Servived'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-5036c4d0ae98> in <module>()
#       1 df['Sex'] = [0 if df['Sex'][i]=='male' else 1 for i in df.index]
# ----> 2 df.groupby(['Sex'])['Servived'].mean()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1608                 stacklevel=2,
#    1609             )
# -> 1610         return super().__getitem__(key)
#    1611
#    1612     def _gotitem(self, key, ndim: int, subset=None):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/base.py in __getitem__(self, key)
#     226         else:
#     227             if key not in self.obj:
# --> 228                 raise KeyError(f"Column not found: {key}")
#     229             return self._gotitem(key, ndim=1)
#     230
#
# KeyError: 'Column not found: Servived'

# %% [markdown]
# ### It shows,female passengers have more chance of surviving than male ones.
# ### It shows women were prioritized over men.

# %%
df.groupby(['Embarked'])['Servived'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-4c4834c90eb7> in <module>()
# ----> 1 df.groupby(['Embarked'])['Servived'].mean()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1608                 stacklevel=2,
#    1609             )
# -> 1610         return super().__getitem__(key)
#    1611
#    1612     def _gotitem(self, key, ndim: int, subset=None):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/base.py in __getitem__(self, key)
#     226         else:
#     227             if key not in self.obj:
# --> 228                 raise KeyError(f"Column not found: {key}")
#     229             return self._gotitem(key, ndim=1)
#     230
#
# KeyError: 'Column not found: Servived'

# %% [markdown]
# # **CONCLUSION**

# %% [markdown]
# * Female passengers were prioritized over men.
# * People with high class or rich people have higher survival rate than others. The heirarichy might have been followed while saving the passangers.
# * Passengers  travelling with their family have heigher survival rate.
# * Passengers who borded the ship at Cherbourg, survived more in proportion then the others.
